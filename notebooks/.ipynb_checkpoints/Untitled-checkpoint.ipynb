# %%
import pycaret
import pandas as pd
from pycaret.regression import *
import os

# %%
os.listdir('data')
# Out:
# ['test.csv', 'data_description.txt', 'train.csv', 'sample_submission.csv']

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv("data/test.csv")
train.shape
# Out:
# (1460, 81)

# %%
s = setup(data=train, target='SalePrice', silent=True, use_gpu=True)
# Out:
# <style type="text/css">
# #T_d4a6e_row3_col1, #T_d4a6e_row16_col1, #T_d4a6e_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d4a6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4a6e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d4a6e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4a6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4a6e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d4a6e_row0_col1" class="data row0 col1" >7304</td>
#     </tr>
#     <tr>
#       <th id="T_d4a6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4a6e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d4a6e_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
# ...

# %%
# %%time
best=compare_models(verbose = True, )
# Out:
# <style type="text/css">
# #T_1d96e th {
#   text-align: left;
# }
# ...

# %%
# %%time
best=compare_models(verbose = True, )
# Out:
# <style type="text/css">
# #T_a1b83 th {
#   text-align: left;
# }
# ...

# %%
predict_model(best,data=test)[['Id','Label']].rename(columns={'Label':'SalePrice'}).set_index('Id')#.to_csv('preds.csv')

# %%
# No GPU 21 with GPU 120
